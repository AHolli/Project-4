# %%
# Import dependencies
import pandas as pd
from pathlib import Path

# %%
# Read the data file with the Pandas library
data = Path("C:/Users/mrshw/OneDrive/Desktop/heart_attack_prediction_dataset.csv")
df = pd.read_csv(data)
df.head()
# Out:
#   Patient ID  Age     Sex  Cholesterol Blood Pressure  Heart Rate  Diabetes  \
# 0    BMW7812   67    Male          208         158/88          72         0
# 1    CZE1114   21    Male          389         165/93          98         1
# 2    BNI9906   21  Female          324         174/99          72         1
# 3    JLN3497   84    Male          383        163/100          73         1
# 4    GFO8847   66    Male          318          91/88          93         1
#
#    Family History  Smoking  Obesity  ...  Sedentary Hours Per Day  Income  \
# 0               0        1        0  ...                 6.615001  261404
# 1               1        1        1  ...                 4.963459  285768
# 2               0        0        0  ...                 9.463426  235282
# 3               1        1        0  ...                 7.648981  125640
# 4               1        1        1  ...                 1.514821  160555
#
#          BMI  Triglycerides  Physical Activity Days Per Week  \
# ...

# %%
# Gather descriptive statistics of the dataframe.
df.describe()
# Out:
#                Age  Cholesterol   Heart Rate     Diabetes  Family History  \
# count  8763.000000  8763.000000  8763.000000  8763.000000     8763.000000
# mean     53.707977   259.877211    75.021682     0.652288        0.492982
# std      21.249509    80.863276    20.550948     0.476271        0.499979
# min      18.000000   120.000000    40.000000     0.000000        0.000000
# 25%      35.000000   192.000000    57.000000     0.000000        0.000000
# 50%      54.000000   259.000000    75.000000     1.000000        0.000000
# 75%      72.000000   330.000000    93.000000     1.000000        1.000000
# max      90.000000   400.000000   110.000000     1.000000        1.000000
#
#            Smoking      Obesity  Alcohol Consumption  Exercise Hours Per Week  \
# count  8763.000000  8763.000000          8763.000000              8763.000000
# mean      0.896839     0.501426             0.598083                10.014284
# ...

# %%
# Identify incomplete rows.
df.count()
# Out:
# Patient ID                         8763
# Age                                8763
# Sex                                8763
# Cholesterol                        8763
# Blood Pressure                     8763
# Heart Rate                         8763
# Diabetes                           8763
# Family History                     8763
# Smoking                            8763
# Obesity                            8763
# Alcohol Consumption                8763
# Exercise Hours Per Week            8763
# Diet                               8763
# Previous Heart Problems            8763
# Medication Use                     8763
# Stress Level                       8763
# Sedentary Hours Per Day            8763
# Income                             8763
# BMI                                8763
# Triglycerides                      8763
# Physical Activity Days Per Week    8763
# Sleep Hours Per Day                8763
# Country                            8763
# ...

# %%
# There are no incomplete rows.

# %%
# Display overview of Sex column
df['Sex'].value_counts()
# Out:
# Sex
# Male      6111
# Female    2652
# Name: count, dtype: int64

# %%
#Display overview of Continent column
df['Continent'].value_counts()
# Out:
# Continent
# Asia             2543
# Europe           2241
# South America    1362
# Australia         884
# Africa            873
# North America     860
# Name: count, dtype: int64

# %%
# %matplotlib notebook
# %matplotlib widget

# %%
# Dependencies
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
# Read CSV file
heart_data = pd.read_csv("C:/Users/mrshw/OneDrive/Desktop/heart_attack_prediction_dataset.csv")
heart_data.head()
# Out:
#   Patient ID  Age     Sex  Cholesterol Blood Pressure  Heart Rate  Diabetes  \
# 0    BMW7812   67    Male          208         158/88          72         0
# 1    CZE1114   21    Male          389         165/93          98         1
# 2    BNI9906   21  Female          324         174/99          72         1
# 3    JLN3497   84    Male          383        163/100          73         1
# 4    GFO8847   66    Male          318          91/88          93         1
#
#    Family History  Smoking  Obesity  ...  Sedentary Hours Per Day  Income  \
# 0               0        1        0  ...                 6.615001  261404
# 1               1        1        1  ...                 4.963459  285768
# 2               0        0        0  ...                 9.463426  235282
# 3               1        1        0  ...                 7.648981  125640
# 4               1        1        1  ...                 1.514821  160555
#
#          BMI  Triglycerides  Physical Activity Days Per Week  \
# ...

# %%
# List the columns
heart_data.columns
# Out:
# Index(['Patient ID', 'Age', 'Sex', 'Cholesterol', 'Blood Pressure',
#        'Heart Rate', 'Diabetes', 'Family History', 'Smoking', 'Obesity',
#        'Alcohol Consumption', 'Exercise Hours Per Week', 'Diet',
#        'Previous Heart Problems', 'Medication Use', 'Stress Level',
#        'Sedentary Hours Per Day', 'Income', 'BMI', 'Triglycerides',
#        'Physical Activity Days Per Week', 'Sleep Hours Per Day', 'Country',
#        'Continent', 'Hemisphere', 'Heart Attack Risk'],
#       dtype='object')

# %%
# Create a dataframe with columns to total certain categories.
heart_totals_data = heart_data[["Age", "Sex", "Obesity", "Continent", "Heart Attack Risk"]]
heart_totals_data.head()
# Out:
#    Age     Sex  Obesity      Continent  Heart Attack Risk
# 0   67    Male        0  South America                  0
# 1   21    Male        1  North America                  0
# 2   21  Female        0         Europe                  0
# 3   84    Male        0  North America                  0
# 4   66    Male        1           Asia                  0

# %%
# Set x axis and tick locations
x_axis = np.arange(len(heart_totals_data))
tick_locations = [value for value in x_axis]

# %%
pdf.pivot(index="Continent",columns="Heart Attack Risk",values="count").plot(kind="bar",stacked=True)
# Out:
# <Axes: xlabel='Continent'>
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# Get total settlements by union
continent_data = heart_totals_data["Continent"].value_counts()

# %%
# Configure plot, figsize, title, and axis labels
figure1 = continent_data.plot(kind="bar", facecolor="red", figsize=(10,8),
                                title="Male/Female Participants by Continent",
                                xlabel="Continent",
                                ylabel="Sex")

# Configure x-tick rotation
xticklabels = continent_data.index
figure1.set_xticklabels(xticklabels, rotation=45, rotation_mode="anchor", ha="right", wrap=True)


# Show plot
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
